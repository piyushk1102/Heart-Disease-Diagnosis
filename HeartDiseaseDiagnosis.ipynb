# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as pyplot
import seaborn as sns

# %%
data = pd.read_csv("Heart Disease data.csv")

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df=data

# %%
df.isnull()
# Out:
#         age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0     False  False  False     False  False  False    False    False  False
# 1     False  False  False     False  False  False    False    False  False
# 2     False  False  False     False  False  False    False    False  False
# 3     False  False  False     False  False  False    False    False  False
# 4     False  False  False     False  False  False    False    False  False
# ...     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 1020  False  False  False     False  False  False    False    False  False
# 1021  False  False  False     False  False  False    False    False  False
# 1022  False  False  False     False  False  False    False    False  False
# 1023  False  False  False     False  False  False    False    False  False
# 1024  False  False  False     False  False  False    False    False  False
#
#       oldpeak  slope     ca   thal  target
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16,9))
sns.heatmap(data.select_dtypes(include=['number']).corr(method='pearson'), annot=True, vmin=-1, vmax=1, cmap='YlGnBu')
plt.show()

# %%
target=data.groupby('target').size()
target
# Out:
# target
# 0    499
# 1    526
# dtype: int64

# %%
def heart_disease(row):
    if row==0:
        return 'Absent'
    elif row==1:
        return 'Present'

# %%
data['Heart_Disease']=data['target'].apply(heart_disease)

# %%
def gender(row):
    if row==1:
        return 'Male'
    elif row==0:
        return 'Female'

# %%
data['Gender']=data['sex'].apply(gender)

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# 5      58    0   0       100   248    0        0      122      0      1.0
# 6      58    1   0       114   318    0        2      140      0      4.4
# 7      55    1   0       160   289    0        0      145      1      0.8
# 8      46    1   0       120   249    0        0      144      0      0.8
# 9      54    1   0       122   286    0        0      116      1      3.2
# 10     71    0   0       112   149    0        1      125      0      1.6
# 11     43    0   0       132   341    1        0      136      1      3.0
# ...

# %%
#Pie Chart

import pandas as pd
import matplotlib.pyplot as plt

counts = data['Heart_Disease'].value_counts()

plt.figure(figsize=(20,20))
plt.pie(sizes, labels=['Present','Absent'], autopct='%0.0f%%', colors=['#66b3ff','#ff9999'], startangle=140)
plt.title('Heart Disease Population %', fontsize=20)
plt.show()

# %%
#Countplot

import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
sns.countplot(x='age', data=data)
plt.title('Population Age', fontsize=20)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.show()

# %%
#Statistical Analysis

Min_Age=data['age'].min()
Max_Age=data['age'].max()
Mean_Age=data['age'].mean()
print("Minimum Age =",Min_Age)
print("Maximum Age =",Max_Age)
print("Mean Age =",Mean_Age)
# Out:
# Minimum Age = 29
# Maximum Age = 77
# Mean Age = 54.43414634146342

# %%
#Categorical Analysis

Young_Ages=data[(data['age']>=29) & (data['age']<40)]
Middle_Ages=data[(data['age']>=40) & (data['age']<55)]
Elderly_Ages=data[(data['age']>55)]
print('Young Ages =',len(Young_Ages))
print('Middle Ages =',len(Middle_Ages))
print('Elderly Ages =',len(Elderly_Ages))
# Out:
# Young Ages = 57
# Middle Ages = 419
# Elderly Ages = 519

# %%
#Bar Plot Creation of Age Category

import matplotlib.pyplot as pyplot
import seaborn as sns

plt.figure(figsize=(10,7))
sns.barplot(x=['Young','Middle','Elderly'], y=[len(Young_Ages), len(Middle_Ages), len(Elderly_Ages)], palette='YlOrBr')
plt.title('Age Category', fontsize=20)
plt.xlabel('Age Range', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
def age_range(row):
    if row>=29 and row<40:
        return 'Young Age'
    elif row>=40 and row<55:
        return 'Middle Age'
    elif row>=55:
        return 'Elder Age'

# %%
data['Age_Range']=data['age'].apply(age_range)

# %%
data
# Out:
#       age  sex cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1  0       125   212    0        1      168      0      1.0
# 1      53    1  0       140   203    1        0      155      1      3.1
# 2      70    1  0       145   174    0        1      125      1      2.6
# 3      61    1  0       148   203    0        1      161      0      0.0
# 4      62    0  0       138   294    1        1      106      0      1.9
# 5      58    0  0       100   248    0        0      122      0      1.0
# 6      58    1  0       114   318    0        2      140      0      4.4
# 7      55    1  0       160   289    0        0      145      1      0.8
# 8      46    1  0       120   249    0        0      144      0      0.8
# 9      54    1  0       122   286    0        0      116      1      3.2
# 10     71    0  0       112   149    0        1      125      0      1.6
# 11     43    0  0       132   341    1        0      136      1      3.0
# ...

# %%
#Swarm Plot for Gender Based Age Category

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20,20))
sns.swarmplot(x='Age_Range', y='age', hue='Gender', data=data, order=['Young Age','Middle Age','Elder Age'], palette='Oranges_r')
plt.title('Gender Based Age Category', fontsize=25)
plt.xlabel('Age Category', fontsize=20)
plt.ylabel('Age', fontsize=20)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Strip Plot for Gender Based Age Category

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,10))
sns.stripplot(x='Age_Range', y='age', hue='Gender', data=data, order=['Young Age','Middle Age','Elder Age'], palette='Oranges_r', dodge=True)
plt.title('Gender Based Age Category', fontsize=20)
plt.xlabel('Age Category', fontsize=15)
plt.ylabel('Age', fontsize=15)
plt.legend(title='Sex', loc='best')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Count Plot for Heart Disease Based On Age Category

plt.figure(figsize=(10,10))
hue_order=['Young Age', 'Middle Age', 'Elder Age']
sns.countplot(x='Heart_Disease', hue='Age_Range', data=data, order=['Present','Absent'], hue_order=hue_order, palette='Pastel1')
plt.title('Heart Disease Based On Age Category', fontsize=20)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %%
 #Count Plot for Heart Disease Based on Gender

plt.figure(figsize=(10,10))
sns.countplot(x=data['Heart_Disease'], hue='Gender', data=data, palette='BuGn')
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.legend(labels=['Male','Female'])
plt.title('Heart Disease Based on Gender',fontsize=20)
plt.show()

# %%
data['Gender'] = data['Gender'].astype(str)
data['cp'] = data['cp'].astype(str)

# %%
#Count Plot for Chest Pain Experienced

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 10))
sns.countplot(x='Heart_Disease', hue='cp', data=data, order=['Present', 'Absent'], palette='viridis')

plt.title('Chest Pain Experienced', fontsize=20)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.legend(title='Chest Pain Type', labels=['Typical Angina', 'Atypical Angina', 'Non-Anginal pain', 'Asymptomatic'])
plt.show()

# %%
#Count Plot for Chest Pain Based On Gender

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 10))
sns.countplot(x='Gender', hue='cp', data=data, palette='Set2')

plt.title('Chest Pain Based On Gender', fontsize=20)
plt.xlabel('Gender', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.legend(title='Chest Pain Type', labels=['Typical Angina', 'Atypical Angina', 'Non-Anginal pain', 'Asymptomatic'])

plt.show()

# %%
#Count Plot for Chest Pain Based On Age Category

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 10))
sns.countplot(x=data['Age_Range'], hue='cp', data=data, order=['Young Age', 'Middle Age', 'Elder Age'], palette='Set1')
plt.title('Chest Pain Based On Age Category', fontsize=20)
plt.xlabel('Age Category', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %%
#Bar Plot for Person's Resting Blood Pressure (mm Hg) Based on Gender

import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x='Gender', y='trestbps', data=data, palette='rocket')
plt.title("Blood Pressure", fontsize=20)
plt.xlabel('Gender',fontsize=15)
plt.ylabel("Person's Resting Blood Pressure (mm Hg)", fontsize=12)
plt.show()

# %%
#Bar Plot for Cholestrol Level Based On Gender

sns.barplot(x='Gender', y='chol', data=data, palette='mako')
plt.title("Cholestrol Level Based On Gender", fontsize=20)
plt.xlabel('Sex',fontsize=15)
plt.ylabel("Cholestrol", fontsize=15)
plt.show()

# %%
#Bar Plot for Cholestrol VS Heart Disease

sns.barplot(x='Heart_Disease', y='chol', data=data, palette='flare')
plt.title('Cholestrol VS Heart Disease', fontsize=20)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Cholestrol', fontsize=15)
plt.show()

# %%
#Bar Plot for Blood Pressure VS Heart Disease

sns.barplot(x='Heart_Disease', y='trestbps', data=data, palette='crest')
plt.title('Blood Pressure VS Heart Disease', fontsize=20)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Blood Pressure', fontsize=15)
plt.show()

# %%
#Line Plot for Blood Pressure VS Age

sns.lineplot(x='age', y='trestbps', data=data, color='r')
plt.title('Blood Pressure VS Age', fontsize=20)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Blood Pressure', fontsize=15)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Line Plot for Cholestrol VS Age

sns.lineplot(x='age', y='chol', data=data, color='b')
plt.title('Cholestrol VS Age', fontsize=20)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Cholestrol', fontsize=15)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Line Plot for ST Depression VS Age

sns.lineplot(x='age', y='oldpeak', data=data, color='g')
plt.title('ST Depression VS Age', fontsize=20)
plt.xlabel('Age', fontsize=15)
plt.ylabel('ST depression', fontsize=15)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Bar Plot for ST depression VS Heart Disease

sns.barplot(x='Gender', y='oldpeak', data=data, palette='viridis')
plt.title('ST depression VS Heart Disease', fontsize=20)
plt.xlabel('Gender', fontsize=15)
plt.ylabel('ST depression', fontsize=15)
plt.show()

# %%
#Bar Plot for Exercise With Angina VS Heart Disease

sns.barplot(x='Heart_Disease', y='exang', data=data, palette='plasma')
plt.title('Exercise With Angina VS Heart Disease', fontsize=20)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Exercise With Angina', fontsize=15)
plt.show()

# %%
#Bar Plot for Exercise With Angina VS Gender

sns.barplot(x='Gender', y='exang', data=data, palette='seismic')
plt.title('Exercise With Angina VS Gender', fontsize=20)
plt.xlabel('Gender', fontsize=15)
plt.ylabel('Exercise With Angina', fontsize=15)
plt.show()

# %%
#Bar Plot for Blood Sugar VS Gender

sns.barplot(y='fbs', x='Gender', data=data, palette='magma')
plt.title(' Fasting Blood Sugar VS Gender', fontsize=20)
plt.xlabel('Gender', fontsize=15)
plt.ylabel('Fasting Blood Sugar', fontsize=15)
plt.show()
